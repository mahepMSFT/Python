# %% [markdown]
# <a href="https://colab.research.google.com/github/mahepMSFT/Python/blob/master/Bank_Management_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 'Bank Management App' using Basic Python using functions

# %%
#Create storage for accounts
accounts = {}

# %%
#Function to create new account
def create_account():
    name = input("Enter A/C holder name: ")
    pin = input("Enter PIN number: ")
    deposit = float(input("Enter deposit amount: "))
